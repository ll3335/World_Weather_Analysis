# %%
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import time
from config import g_key
from config import weather_api_key
from citipy import citipy

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=00a87608dc4612046a1ad5ee17987ef6

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city and ensure imperial data is requested
    city_url = url + "&q=" + city + '&units=imperial'

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | kokstad
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | zeya
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | lompoc
# Processing Record 13 of Set 1 | jackson
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | tahoua
# Processing Record 17 of Set 1 | eyl
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | tianpeng
# Processing Record 20 of Set 1 | padang
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | mount isa
# Processing Record 23 of Set 1 | kalmunai
# Processing Record 24 of Set 1 | porto belo
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | tall kayf
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | mahibadhoo
# Processing Record 31 of Set 1 | ribeira brava
# Processing Record 32 of Set 1 | zverinogolovskoye
# Processing Record 33 of Set 1 | owando
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | candido mendes
# Processing Record 36 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 1 | sinegorye
# Processing Record 38 of Set 1 | ruzhyn
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 1 | moorhead
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | pogar
# Processing Record 46 of Set 1 | narsaq
# Processing Record 47 of Set 1 | lagoa
# Processing Record 48 of Set 1 | husavik
# Processing Record 49 of Set 1 | asyut
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | guerrero negro
# Processing Record 4 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | sobolevo
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | warrington
# Processing Record 10 of Set 2 | porto novo
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | vanimo
# Processing Record 13 of Set 2 | port-gentil
# Processing Record 14 of Set 2 | ayan
# Processing Record 15 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | chandbali
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | bathsheba
# Processing Record 23 of Set 2 | cavalcante
# Processing Record 24 of Set 2 | kuryk
# Processing Record 25 of Set 2 | codrington
# Processing Record 26 of Set 2 | tessalit
# Processing Record 27 of Set 2 | cuamba
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | vostok
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | axim
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | maarianhamina
# Processing Record 38 of Set 2 | kailua
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | ushuaia
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | gibara
# Processing Record 43 of Set 2 | aksarka
# Processing Record 44 of Set 2 | poum
# Processing Record 45 of Set 2 | playas
# Processing Record 46 of Set 2 | beringovskiy
# Processing Record 47 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | yarada
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | hamilton
# Processing Record 4 of Set 3 | straumen
# Processing Record 5 of Set 3 | marzuq
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | bukama
# Processing Record 8 of Set 3 | wajima
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 11 of Set 3 | semporna
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | gold coast
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | bandarbeyla
# Processing Record 16 of Set 3 | kenai
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | walvis bay
# Processing Record 20 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 3 | revelstoke
# Processing Record 22 of Set 3 | dasoguz
# Processing Record 23 of Set 3 | chulman
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | baoqing
# Processing Record 26 of Set 3 | portland
# Processing Record 27 of Set 3 | geraldton
# Processing Record 28 of Set 3 | aykhal
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | presidencia roque saenz pena
# Processing Record 31 of Set 3 | san pedro
# Processing Record 32 of Set 3 | angoche
# Processing Record 33 of Set 3 | maniwaki
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | bethel
# Processing Record 36 of Set 3 | antalaha
# Processing Record 37 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | merauke
# Processing Record 40 of Set 3 | pahrump
# Processing Record 41 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | kieta
# Processing Record 44 of Set 3 | katsuura
# Processing Record 45 of Set 3 | boissevain
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | oriximina
# Processing Record 48 of Set 3 | urozhayne
# City not found. Skipping...
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | coquimbo
# Processing Record 1 of Set 4 | karoi
# Processing Record 2 of Set 4 | maragogi
# Processing Record 3 of Set 4 | peniche
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | oistins
# Processing Record 6 of Set 4 | port hardy
# Processing Record 7 of Set 4 | nikolskoye
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | nago
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | turukhansk
# Processing Record 12 of Set 4 | kruisfontein
# Processing Record 13 of Set 4 | havelock
# Processing Record 14 of Set 4 | raga
# Processing Record 15 of Set 4 | port moresby
# Processing Record 16 of Set 4 | harper
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | humberto de campos
# Processing Record 19 of Set 4 | arkhangelsk
# Processing Record 20 of Set 4 | gzhatsk
# City not found. Skipping...
# Processing Record 21 of Set 4 | richards bay
# Processing Record 22 of Set 4 | aswan
# Processing Record 23 of Set 4 | sainte-anne-des-monts
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | abu zabad
# Processing Record 26 of Set 4 | leshukonskoye
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | cockburn town
# Processing Record 29 of Set 4 | bara
# Processing Record 30 of Set 4 | ketchikan
# Processing Record 31 of Set 4 | rundu
# Processing Record 32 of Set 4 | nantucket
# Processing Record 33 of Set 4 | camana
# Processing Record 34 of Set 4 | dombarovskiy
# Processing Record 35 of Set 4 | killin
# Processing Record 36 of Set 4 | laguna de perlas
# Processing Record 37 of Set 4 | ixtapa
# Processing Record 38 of Set 4 | muravlenko
# Processing Record 39 of Set 4 | auki
# Processing Record 40 of Set 4 | salalah
# Processing Record 41 of Set 4 | talnakh
# Processing Record 42 of Set 4 | hilo
# Processing Record 43 of Set 4 | la ligua
# Processing Record 44 of Set 4 | saint augustine
# Processing Record 45 of Set 4 | imeni poliny osipenko
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | winnemucca
# Processing Record 48 of Set 4 | alofi
# Processing Record 49 of Set 4 | rocha
# Processing Record 50 of Set 4 | hovd
# Processing Record 1 of Set 5 | irbil
# Processing Record 2 of Set 5 | qaanaaq
# Processing Record 3 of Set 5 | itarema
# Processing Record 4 of Set 5 | weiser
# Processing Record 5 of Set 5 | kodiak
# Processing Record 6 of Set 5 | aklavik
# Processing Record 7 of Set 5 | alice springs
# Processing Record 8 of Set 5 | rio branco
# Processing Record 9 of Set 5 | sterling
# Processing Record 10 of Set 5 | quatre cocos
# Processing Record 11 of Set 5 | seymchan
# Processing Record 12 of Set 5 | garowe
# Processing Record 13 of Set 5 | oussouye
# Processing Record 14 of Set 5 | surgut
# Processing Record 15 of Set 5 | santa maria del oro
# Processing Record 16 of Set 5 | kalamakion
# City not found. Skipping...
# Processing Record 17 of Set 5 | ancud
# Processing Record 18 of Set 5 | nowy targ
# Processing Record 19 of Set 5 | margate
# Processing Record 20 of Set 5 | saint-pie
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | constitucion
# Processing Record 23 of Set 5 | north myrtle beach
# Processing Record 24 of Set 5 | khandyga
# Processing Record 25 of Set 5 | lorengau
# Processing Record 26 of Set 5 | skjervoy
# Processing Record 27 of Set 5 | praia da vitoria
# Processing Record 28 of Set 5 | mehamn
# Processing Record 29 of Set 5 | matamoros
# Processing Record 30 of Set 5 | san patricio
# Processing Record 31 of Set 5 | faanui
# Processing Record 32 of Set 5 | port elizabeth
# Processing Record 33 of Set 5 | kudahuvadhoo
# Processing Record 34 of Set 5 | mukhen
# Processing Record 35 of Set 5 | namatanai
# Processing Record 36 of Set 5 | viedma
# Processing Record 37 of Set 5 | kungurtug
# Processing Record 38 of Set 5 | laguna
# Processing Record 39 of Set 5 | russell
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | ullal
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | yulara
# Processing Record 44 of Set 5 | mitsamiouli
# Processing Record 45 of Set 5 | cubarral
# Processing Record 46 of Set 5 | eydhafushi
# Processing Record 47 of Set 5 | pangnirtung
# Processing Record 48 of Set 5 | silae
# Processing Record 49 of Set 5 | twin falls
# Processing Record 50 of Set 5 | tsabong
# Processing Record 1 of Set 6 | bone
# Processing Record 2 of Set 6 | coahuayana
# Processing Record 3 of Set 6 | kantang
# Processing Record 4 of Set 6 | mairwa
# Processing Record 5 of Set 6 | terre-de-bas
# Processing Record 6 of Set 6 | airai
# Processing Record 7 of Set 6 | moncao
# Processing Record 8 of Set 6 | rennes
# Processing Record 9 of Set 6 | mar del plata
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | puerto del rosario
# Processing Record 12 of Set 6 | altay
# Processing Record 13 of Set 6 | klaksvik
# Processing Record 14 of Set 6 | mizdah
# Processing Record 15 of Set 6 | alikalia
# Processing Record 16 of Set 6 | sao filipe
# Processing Record 17 of Set 6 | jalu
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | makakilo city
# Processing Record 20 of Set 6 | ahipara
# Processing Record 21 of Set 6 | ambajogai
# Processing Record 22 of Set 6 | pohrebyshche
# Processing Record 23 of Set 6 | istok
# Processing Record 24 of Set 6 | sabang
# Processing Record 25 of Set 6 | maniitsoq
# Processing Record 26 of Set 6 | bay roberts
# Processing Record 27 of Set 6 | bandrele
# Processing Record 28 of Set 6 | buxar
# Processing Record 29 of Set 6 | ubinskoye
# Processing Record 30 of Set 6 | nouakchott
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | egvekinot
# Processing Record 33 of Set 6 | san cristobal
# Processing Record 34 of Set 6 | idaho falls
# Processing Record 35 of Set 6 | kamariotissa
# Processing Record 36 of Set 6 | hobyo
# Processing Record 37 of Set 6 | kaeo
# Processing Record 38 of Set 6 | sitka
# Processing Record 39 of Set 6 | karratha
# Processing Record 40 of Set 6 | teruel
# Processing Record 41 of Set 6 | orlik
# Processing Record 42 of Set 6 | samarai
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | puerto ayacucho
# Processing Record 45 of Set 6 | vestmannaeyjar
# Processing Record 46 of Set 6 | det udom
# Processing Record 47 of Set 6 | saint anthony
# Processing Record 48 of Set 6 | matveyev kurgan
# Processing Record 49 of Set 6 | maceio
# Processing Record 50 of Set 6 | rogers
# Processing Record 1 of Set 7 | nioro
# Processing Record 2 of Set 7 | kaduna
# Processing Record 3 of Set 7 | antofagasta
# Processing Record 4 of Set 7 | korla
# Processing Record 5 of Set 7 | sargatskoye
# Processing Record 6 of Set 7 | evanston
# Processing Record 7 of Set 7 | tabou
# Processing Record 8 of Set 7 | beira
# Processing Record 9 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 7 | nanortalik
# Processing Record 11 of Set 7 | ankang
# Processing Record 12 of Set 7 | mayma
# Processing Record 13 of Set 7 | havoysund
# Processing Record 14 of Set 7 | puerto carreno
# Processing Record 15 of Set 7 | varzob
# Processing Record 16 of Set 7 | krasnoselkup
# Processing Record 17 of Set 7 | odweyne
# Processing Record 18 of Set 7 | biak
# Processing Record 19 of Set 7 | kavieng
# Processing Record 20 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 7 | eregli
# Processing Record 22 of Set 7 | rudnogorsk
# Processing Record 23 of Set 7 | saint-louis
# Processing Record 24 of Set 7 | cherskiy
# Processing Record 25 of Set 7 | havre-saint-pierre
# Processing Record 26 of Set 7 | umm kaddadah
# Processing Record 27 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 7 | katobu
# Processing Record 29 of Set 7 | mahuva
# Processing Record 30 of Set 7 | ust-kishert
# Processing Record 31 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 7 | meulaboh
# Processing Record 33 of Set 7 | okato
# Processing Record 34 of Set 7 | vila franca do campo
# Processing Record 35 of Set 7 | christchurch
# Processing Record 36 of Set 7 | skibbereen
# Processing Record 37 of Set 7 | santa maria
# Processing Record 38 of Set 7 | abu samrah
# Processing Record 39 of Set 7 | kavaratti
# Processing Record 40 of Set 7 | tindivanam
# Processing Record 41 of Set 7 | broken hill
# Processing Record 42 of Set 7 | mitu
# Processing Record 43 of Set 7 | baykit
# Processing Record 44 of Set 7 | cascais
# Processing Record 45 of Set 7 | hambantota
# Processing Record 46 of Set 7 | sakib
# Processing Record 47 of Set 7 | binabalian
# Processing Record 48 of Set 7 | charagua
# Processing Record 49 of Set 7 | sangar
# Processing Record 50 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 1 of Set 8 | neryungri
# Processing Record 2 of Set 8 | paamiut
# Processing Record 3 of Set 8 | barcelos
# Processing Record 4 of Set 8 | tazovskiy
# Processing Record 5 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 8 | burgeo
# Processing Record 7 of Set 8 | pitimbu
# Processing Record 8 of Set 8 | touros
# Processing Record 9 of Set 8 | navolato
# Processing Record 10 of Set 8 | marathon
# Processing Record 11 of Set 8 | riyadh
# Processing Record 12 of Set 8 | misawa
# Processing Record 13 of Set 8 | zhezkazgan
# Processing Record 14 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 8 | gizo
# Processing Record 16 of Set 8 | dauriya
# Processing Record 17 of Set 8 | champagnole
# Processing Record 18 of Set 8 | zhongxing
# Processing Record 19 of Set 8 | cabo san lucas
# Processing Record 20 of Set 8 | vila velha
# Processing Record 21 of Set 8 | norrkoping
# Processing Record 22 of Set 8 | sao felix do xingu
# Processing Record 23 of Set 8 | carutapera
# Processing Record 24 of Set 8 | ternate
# Processing Record 25 of Set 8 | pacific grove
# Processing Record 26 of Set 8 | tarrafal
# Processing Record 27 of Set 8 | algarrobo
# Processing Record 28 of Set 8 | bambous virieux
# Processing Record 29 of Set 8 | banfora
# Processing Record 30 of Set 8 | anloga
# Processing Record 31 of Set 8 | salinas
# Processing Record 32 of Set 8 | porto santo
# Processing Record 33 of Set 8 | prince rupert
# Processing Record 34 of Set 8 | flinders
# Processing Record 35 of Set 8 | zonguldak
# Processing Record 36 of Set 8 | saint-philippe
# Processing Record 37 of Set 8 | suntar
# Processing Record 38 of Set 8 | anaconda
# Processing Record 39 of Set 8 | vanavara
# Processing Record 40 of Set 8 | nelson bay
# Processing Record 41 of Set 8 | ambon
# Processing Record 42 of Set 8 | uthal
# Processing Record 43 of Set 8 | lexington
# Processing Record 44 of Set 8 | gotsu
# Processing Record 45 of Set 8 | goderich
# Processing Record 46 of Set 8 | chachapoyas
# Processing Record 47 of Set 8 | bubaque
# Processing Record 48 of Set 8 | tongliao
# Processing Record 49 of Set 8 | comodoro rivadavia
# Processing Record 50 of Set 8 | guaruja
# Processing Record 1 of Set 9 | cap malheureux
# Processing Record 2 of Set 9 | moron
# Processing Record 3 of Set 9 | tarpon springs
# Processing Record 4 of Set 9 | umm lajj
# Processing Record 5 of Set 9 | mangan
# Processing Record 6 of Set 9 | ryotsu
# Processing Record 7 of Set 9 | hauterive
# Processing Record 8 of Set 9 | iracoubo
# Processing Record 9 of Set 9 | inuvik
# Processing Record 10 of Set 9 | inta
# Processing Record 11 of Set 9 | ferkessedougou
# Processing Record 12 of Set 9 | luanda
# Processing Record 13 of Set 9 | mount gambier
# Processing Record 14 of Set 9 | ambovombe
# Processing Record 15 of Set 9 | shimoda
# Processing Record 16 of Set 9 | saint george
# Processing Record 17 of Set 9 | nea peramos
# Processing Record 18 of Set 9 | luderitz
# Processing Record 19 of Set 9 | agadez
# Processing Record 20 of Set 9 | port blair
# Processing Record 21 of Set 9 | batemans bay
# Processing Record 22 of Set 9 | shakawe
# Processing Record 23 of Set 9 | zambezi
# Processing Record 24 of Set 9 | camacari
# Processing Record 25 of Set 9 | sulphur
# Processing Record 26 of Set 9 | brattleboro
# Processing Record 27 of Set 9 | sai buri
# Processing Record 28 of Set 9 | provost
# Processing Record 29 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | rangapara
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 34 of Set 9 | talaya
# Processing Record 35 of Set 9 | moyale
# Processing Record 36 of Set 9 | matara
# Processing Record 37 of Set 9 | caravelas
# Processing Record 38 of Set 9 | nome
# Processing Record 39 of Set 9 | pontal do parana
# Processing Record 40 of Set 9 | vardo
# Processing Record 41 of Set 9 | bilibino
# Processing Record 42 of Set 9 | ngunguru
# Processing Record 43 of Set 9 | los llanos de aridane
# Processing Record 44 of Set 9 | southbridge
# Processing Record 45 of Set 9 | tromso
# Processing Record 46 of Set 9 | northam
# Processing Record 47 of Set 9 | kununurra
# Processing Record 48 of Set 9 | cassilandia
# Processing Record 49 of Set 9 | poltava
# Processing Record 50 of Set 9 | batamshinskiy
# Processing Record 1 of Set 10 | jacksonville
# Processing Record 2 of Set 10 | nuuk
# Processing Record 3 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 10 | trnava
# Processing Record 5 of Set 10 | katherine
# Processing Record 6 of Set 10 | launceston
# Processing Record 7 of Set 10 | morehead
# Processing Record 8 of Set 10 | challapata
# Processing Record 9 of Set 10 | guata
# City not found. Skipping...
# Processing Record 10 of Set 10 | panorama
# Processing Record 11 of Set 10 | uaua
# Processing Record 12 of Set 10 | coos bay
# Processing Record 13 of Set 10 | pinos
# Processing Record 14 of Set 10 | lavrentiya
# Processing Record 15 of Set 10 | tokur
# Processing Record 16 of Set 10 | palmer
# Processing Record 17 of Set 10 | luau
# Processing Record 18 of Set 10 | grindavik
# Processing Record 19 of Set 10 | ouallam
# Processing Record 20 of Set 10 | rawson
# Processing Record 21 of Set 10 | pierre
# Processing Record 22 of Set 10 | roebourne
# Processing Record 23 of Set 10 | bouillante
# Processing Record 24 of Set 10 | livramento
# Processing Record 25 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 26 of Set 10 | kyra
# Processing Record 27 of Set 10 | houston
# Processing Record 28 of Set 10 | salamanca
# Processing Record 29 of Set 10 | teplyk
# Processing Record 30 of Set 10 | opuwo
# Processing Record 31 of Set 10 | pringsewu
# Processing Record 32 of Set 10 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 33 of Set 10 | dicabisagan
# Processing Record 34 of Set 10 | itoman
# Processing Record 35 of Set 10 | camocim
# Processing Record 36 of Set 10 | zhangye
# Processing Record 37 of Set 10 | sault sainte marie
# Processing Record 38 of Set 10 | wanning
# Processing Record 39 of Set 10 | aguada de pasajeros
# Processing Record 40 of Set 10 | biloxi
# Processing Record 41 of Set 10 | djenne
# Processing Record 42 of Set 10 | sale
# Processing Record 43 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 10 | kampot
# Processing Record 45 of Set 10 | pordim
# Processing Record 46 of Set 10 | swellendam
# Processing Record 47 of Set 10 | bucerias
# Processing Record 48 of Set 10 | olafsvik
# Processing Record 49 of Set 10 | sakakah
# Processing Record 50 of Set 10 | tigre
# Processing Record 1 of Set 11 | deputatskiy
# Processing Record 2 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 11 | mairang
# Processing Record 4 of Set 11 | elizabeth city
# Processing Record 5 of Set 11 | sinazongwe
# Processing Record 6 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 11 | kargasok
# Processing Record 8 of Set 11 | aranos
# Processing Record 9 of Set 11 | huarmey
# Processing Record 10 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 11 of Set 11 | beirut
# Processing Record 12 of Set 11 | mattru
# Processing Record 13 of Set 11 | tomigusuku
# Processing Record 14 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 11 | kotli loharan
# Processing Record 16 of Set 11 | bannu
# Processing Record 17 of Set 11 | paraiso
# Processing Record 18 of Set 11 | naze
# Processing Record 19 of Set 11 | yar-sale
# Processing Record 20 of Set 11 | kongolo
# Processing Record 21 of Set 11 | bonthe
# Processing Record 22 of Set 11 | linqiong
# Processing Record 23 of Set 11 | tatawin
# Processing Record 24 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 25 of Set 11 | upata
# Processing Record 26 of Set 11 | dali
# Processing Record 27 of Set 11 | khiri mat
# Processing Record 28 of Set 11 | lapua
# Processing Record 29 of Set 11 | leningradskiy
# Processing Record 30 of Set 11 | beloha
# Processing Record 31 of Set 11 | sao jose da coroa grande
# Processing Record 32 of Set 11 | kapoeta
# Processing Record 33 of Set 11 | shishou
# Processing Record 34 of Set 11 | maryville
# Processing Record 35 of Set 11 | ola
# Processing Record 36 of Set 11 | byron bay
# Processing Record 37 of Set 11 | gangapur
# Processing Record 38 of Set 11 | polyarnyy
# Processing Record 39 of Set 11 | ostrovnoy
# Processing Record 40 of Set 11 | tiznit
# Processing Record 41 of Set 11 | tutoia
# Processing Record 42 of Set 11 | borogontsy
# Processing Record 43 of Set 11 | warri
# Processing Record 44 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 11 | port-cartier
# Processing Record 46 of Set 11 | lasa
# Processing Record 47 of Set 11 | isangel
# Processing Record 48 of Set 11 | okha
# Processing Record 49 of Set 11 | dawlatabad
# Processing Record 50 of Set 11 | avigliana
# Processing Record 1 of Set 12 | bonavista
# Processing Record 2 of Set 12 | nagua
# Processing Record 3 of Set 12 | melita
# Processing Record 4 of Set 12 | sayyan
# Processing Record 5 of Set 12 | agua prieta
# Processing Record 6 of Set 12 | notodden
# Processing Record 7 of Set 12 | baglung
# Processing Record 8 of Set 12 | bialogard
# Processing Record 9 of Set 12 | cuenca
# Processing Record 10 of Set 12 | bud
# Processing Record 11 of Set 12 | leh
# Processing Record 12 of Set 12 | griffith
# Processing Record 13 of Set 12 | durazno
# Processing Record 14 of Set 12 | sur
# Processing Record 15 of Set 12 | beidao
# Processing Record 16 of Set 12 | zarubino
# Processing Record 17 of Set 12 | povenets
# Processing Record 18 of Set 12 | yuci
# Processing Record 19 of Set 12 | mandla
# Processing Record 20 of Set 12 | phalodi
# Processing Record 21 of Set 12 | umea
# Processing Record 22 of Set 12 | atagay
# Processing Record 23 of Set 12 | dakar
# Processing Record 24 of Set 12 | flin flon
# Processing Record 25 of Set 12 | east stroudsburg
# Processing Record 26 of Set 12 | otradnoye
# Processing Record 27 of Set 12 | sinnamary
# Processing Record 28 of Set 12 | verkh-usugli
# Processing Record 29 of Set 12 | fallon
# Processing Record 30 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 31 of Set 12 | quijingue
# Processing Record 32 of Set 12 | evensk
# Processing Record 33 of Set 12 | lazurne
# Processing Record 34 of Set 12 | omboue
# Processing Record 35 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 12 | rawlins
# Processing Record 37 of Set 12 | bhachau
# Processing Record 38 of Set 12 | adrar
# Processing Record 39 of Set 12 | george town
# Processing Record 40 of Set 12 | san rafael
# Processing Record 41 of Set 12 | sao paulo de olivenca
# Processing Record 42 of Set 12 | quang ngai
# Processing Record 43 of Set 12 | bambari
# Processing Record 44 of Set 12 | seoul
# Processing Record 45 of Set 12 | mezen
# Processing Record 46 of Set 12 | xuddur
# Processing Record 47 of Set 12 | kerouane
# Processing Record 48 of Set 12 | diego de almagro
# Processing Record 49 of Set 12 | ust-kut
# Processing Record 50 of Set 12 | kyren
# Processing Record 1 of Set 13 | khasan
# Processing Record 2 of Set 13 | camacha
# Processing Record 3 of Set 13 | burica
# City not found. Skipping...
# Processing Record 4 of Set 13 | ondjiva
# Processing Record 5 of Set 13 | avera
# Processing Record 6 of Set 13 | tuatapere
# Processing Record 7 of Set 13 | wuda
# Processing Record 8 of Set 13 | mantua
# Processing Record 9 of Set 13 | shache
# Processing Record 10 of Set 13 | independencia
# Processing Record 11 of Set 13 | severnoye
# Processing Record 12 of Set 13 | the pas
# Processing Record 13 of Set 13 | saravan
# Processing Record 14 of Set 13 | koumac
# Processing Record 15 of Set 13 | basco
# Processing Record 16 of Set 13 | macae
# Processing Record 17 of Set 13 | namibe
# Processing Record 18 of Set 13 | xingyi
# Processing Record 19 of Set 13 | sioux lookout
# Processing Record 20 of Set 13 | uige
# Processing Record 21 of Set 13 | spring hill
# Processing Record 22 of Set 13 | les cayes
# Processing Record 23 of Set 13 | idenao
# Processing Record 24 of Set 13 | gondanglegi
# Processing Record 25 of Set 13 | damara
# Processing Record 26 of Set 13 | murray bridge
# Processing Record 27 of Set 13 | da nang
# Processing Record 28 of Set 13 | hearst
# Processing Record 29 of Set 13 | bafq
# Processing Record 30 of Set 13 | cairns
# Processing Record 31 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 13 | zharkovskiy
# Processing Record 33 of Set 13 | okhotsk
# Processing Record 34 of Set 13 | yaan
# Processing Record 35 of Set 13 | kysyl-syr
# Processing Record 36 of Set 13 | koutsouras
# Processing Record 37 of Set 13 | zapolyarnyy
# Processing Record 38 of Set 13 | safaga
# Processing Record 39 of Set 13 | san juan
# Processing Record 40 of Set 13 | fort nelson
# Processing Record 41 of Set 13 | jiuquan
# Processing Record 42 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 43 of Set 13 | maiduguri
# Processing Record 44 of Set 13 | kutum
# Processing Record 45 of Set 13 | shitanjing
# Processing Record 46 of Set 13 | berezhany
# Processing Record 47 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 48 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 49 of Set 13 | anadyr
# Processing Record 50 of Set 13 | nirasaki
# Processing Record 1 of Set 14 | faya
# Processing Record 2 of Set 14 | zhuhai
# Processing Record 3 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 4 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 14 | khanu woralaksaburi
# Processing Record 6 of Set 14 | pangoa
# Processing Record 7 of Set 14 | kamaishi
# Processing Record 8 of Set 14 | chinhoyi
# Processing Record 9 of Set 14 | awjilah
# Processing Record 10 of Set 14 | broome
# Processing Record 11 of Set 14 | muzhi
# Processing Record 12 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 13 of Set 14 | reading
# Processing Record 14 of Set 14 | lerwick
# Processing Record 15 of Set 14 | alcains
# Processing Record 16 of Set 14 | anastacio
# Processing Record 17 of Set 14 | atambua
# Processing Record 18 of Set 14 | komsomolskiy
# Processing Record 19 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 14 | rio gallegos
# Processing Record 21 of Set 14 | hami
# Processing Record 22 of Set 14 | agua verde
# Processing Record 23 of Set 14 | elko
# Processing Record 24 of Set 14 | sabinas
# Processing Record 25 of Set 14 | noumea
# Processing Record 26 of Set 14 | tecoanapa
# Processing Record 27 of Set 14 | birao
# Processing Record 28 of Set 14 | alekseyevskoye
# Processing Record 29 of Set 14 | diamantino
# Processing Record 30 of Set 14 | sibolga
# Processing Record 31 of Set 14 | sorland
# Processing Record 32 of Set 14 | alugan
# Processing Record 33 of Set 14 | seara
# Processing Record 34 of Set 14 | parana
# Processing Record 35 of Set 14 | lichinga
# Processing Record 36 of Set 14 | beyneu
# Processing Record 37 of Set 14 | san quintin
# Processing Record 38 of Set 14 | saint-leu
# Processing Record 39 of Set 14 | orgun
# City not found. Skipping...
# Processing Record 40 of Set 14 | crepy-en-valois
# Processing Record 41 of Set 14 | muroto
# Processing Record 42 of Set 14 | mikhaylovka
# Processing Record 43 of Set 14 | berikulskiy
# City not found. Skipping...
# Processing Record 44 of Set 14 | alice town
# Processing Record 45 of Set 14 | ebbs
# Processing Record 46 of Set 14 | iquitos
# Processing Record 47 of Set 14 | porbandar
# Processing Record 48 of Set 14 | yichun
# Processing Record 49 of Set 14 | hay river
# Processing Record 50 of Set 14 | nyandoma
# Processing Record 1 of Set 15 | gamba
# Processing Record 2 of Set 15 | charleston
# Processing Record 3 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 15 | sangre grande
# Processing Record 5 of Set 15 | nelspruit
# Processing Record 6 of Set 15 | kurilsk
# Processing Record 7 of Set 15 | farah
# Processing Record 8 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 9 of Set 15 | teknaf
# Processing Record 10 of Set 15 | nanakuli
# Processing Record 11 of Set 15 | victoria
# Processing Record 12 of Set 15 | sola
# Processing Record 13 of Set 15 | palmas bellas
# Processing Record 14 of Set 15 | louis trichardt
# Processing Record 15 of Set 15 | kalengwa
# Processing Record 16 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 17 of Set 15 | the valley
# Processing Record 18 of Set 15 | kitgum
# Processing Record 19 of Set 15 | davila
# Processing Record 20 of Set 15 | otukpo
# Processing Record 21 of Set 15 | kankon
# Processing Record 22 of Set 15 | ortigueira
# Processing Record 23 of Set 15 | hanchuan
# Processing Record 24 of Set 15 | mananjary
# Processing Record 25 of Set 15 | makat
# Processing Record 26 of Set 15 | new glasgow
# Processing Record 27 of Set 15 | tura
# Processing Record 28 of Set 15 | banda aceh
# Processing Record 29 of Set 15 | bahia honda
# Processing Record 30 of Set 15 | nakur
# Processing Record 31 of Set 15 | rovereto
# Processing Record 32 of Set 15 | kinston
# Processing Record 33 of Set 15 | charlottesville
# Processing Record 34 of Set 15 | kanniyakumari
# Processing Record 35 of Set 15 | hofn
# Processing Record 36 of Set 15 | taltal
# Processing Record 37 of Set 15 | zyryanka
# Processing Record 38 of Set 15 | corowa
# Processing Record 39 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 15 | bougouni
# Processing Record 41 of Set 15 | yatou
# Processing Record 42 of Set 15 | westport
# Processing Record 43 of Set 15 | neiafu
# Processing Record 44 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 15 | banyo
# Processing Record 46 of Set 15 | qaqortoq
# Processing Record 47 of Set 15 | maneadero
# Processing Record 48 of Set 15 | barra da estiva
# Processing Record 49 of Set 15 | omalur
# Processing Record 50 of Set 15 | verkhoturye
# Processing Record 1 of Set 16 | kloulklubed
# Processing Record 2 of Set 16 | maymyo
# Processing Record 3 of Set 16 | ballina
# Processing Record 4 of Set 16 | strelka
# Processing Record 5 of Set 16 | smithers
# Processing Record 6 of Set 16 | teahupoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Souillac      MU -20.5167   57.5167     73.78        94          75
# 1  Punta Arenas      CL -53.1500  -70.9167     39.31        60          40
# 2       Kokstad      ZA -30.5472   29.4241     50.68        73          40
# 3      Hermanus      ZA -34.4187   19.2345     52.00        91         100
# 4          Zeya      RU  53.7500  127.2667     41.05        85         100
# 5         Vaini      TO -21.2000 -175.2000     64.56       100          75
# 6         Pevek      RU  69.7008  170.3133     28.45        82           1
# 7     Busselton      AU -33.6500  115.3333     53.04        65          98
# 8       Rikitea      PF -23.1203 -134.9692     76.55        70          67
# 9        Lompoc      US  34.6391 -120.4579     74.37        76          90
#
#    Wind Speed Current Description
# 0        4.90       broken clouds
# 1       18.21    scattered clouds
# 2        3.49    scattered clouds
# 3        3.09     overcast clouds
# 4        3.49     overcast clouds
# 5        2.30       broken clouds
# 6        1.70           clear sky
# 7       12.71     overcast clouds
# 8       22.79       broken clouds
# 9       10.36     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index=False)
